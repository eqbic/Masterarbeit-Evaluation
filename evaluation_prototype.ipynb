# %%
# %load_ext autoreload
# %autoreload 2

# %%
from evaluation.track.track_result_plotter import TrackResultPlotter
from evaluation.common import ResultParam, InputFilter

track_plotter = TrackResultPlotter()
# track_plotter.summary()

# %%
# track_plotter.compare_with_questionnaire()

# %%
track_plotter.print_result(ResultParam.MeanError, InputFilter.InputAll, aggfunc='mean', color=True, plot=True)
# Out:
# <style type="text/css">
# #T_75b9e_row0_col0, #T_75b9e_row0_col1, #T_75b9e_row0_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_75b9e_row1_col0 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_75b9e_row1_col1 {
#   background-color: #ea362a;
#   color: #f1f1f1;
# }
# #T_75b9e_row1_col2, #T_75b9e_row2_col0, #T_75b9e_row2_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_75b9e_row2_col2 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_75b9e_row3_col0 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_75b9e_row3_col1 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_75b9e_row3_col2 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_75b9e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75b9e_level0_col0" class="col_heading level0 col0" colspan="3">mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Track</th>
# ...

# %%
track_plotter.print_result(ResultParam.MedianError, InputFilter.InputAll, aggfunc='mean', color=True, plot=True)
# Out:
# <style type="text/css">
# #T_fe72c_row0_col0 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_fe72c_row0_col1, #T_fe72c_row0_col2, #T_fe72c_row1_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_fe72c_row1_col1 {
#   background-color: #f14331;
#   color: #f1f1f1;
# }
# #T_fe72c_row1_col2, #T_fe72c_row2_col0, #T_fe72c_row2_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_fe72c_row2_col2 {
#   background-color: #de2b25;
#   color: #f1f1f1;
# }
# #T_fe72c_row3_col0 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_fe72c_row3_col1 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_fe72c_row3_col2 {
#   background-color: #fca689;
#   color: #000000;
# }
# </style>
# <table id="T_fe72c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe72c_level0_col0" class="col_heading level0 col0" colspan="3">mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Track</th>
# ...

# %%
track_plotter.print_result(ResultParam.DeltaDistance, InputFilter.InputAll, aggfunc='mean', color=True, plot=True)
# Out:
# <style type="text/css">
# #T_195c6_row0_col0 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_195c6_row0_col1, #T_195c6_row1_col2, #T_195c6_row2_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_195c6_row0_col2 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_195c6_row1_col0 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_195c6_row1_col1 {
#   background-color: #e63328;
#   color: #f1f1f1;
# }
# #T_195c6_row2_col1 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_195c6_row2_col2 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_195c6_row3_col0, #T_195c6_row3_col1, #T_195c6_row3_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_195c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_195c6_level0_col0" class="col_heading level0 col0" colspan="3">mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Track</th>
# ...

# %%
track_plotter.print_result(ResultParam.Time, InputFilter.InputAll, aggfunc='mean', color=True, plot=True)
# Out:
# <style type="text/css">
# #T_cf15e_row0_col0 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_cf15e_row0_col1 {
#   background-color: #7c0510;
#   color: #f1f1f1;
# }
# #T_cf15e_row0_col2, #T_cf15e_row1_col0, #T_cf15e_row1_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_cf15e_row1_col2 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_cf15e_row2_col0, #T_cf15e_row3_col1, #T_cf15e_row3_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_cf15e_row2_col1 {
#   background-color: #c3161b;
#   color: #f1f1f1;
# }
# #T_cf15e_row2_col2 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_cf15e_row3_col0 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cf15e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf15e_level0_col0" class="col_heading level0 col0" colspan="3">mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Track</th>
# ...

# %%
track_plotter.print_result(ResultParam.ZoomChange, InputFilter.InputAll, aggfunc='mean', color=True, plot=True)
# Out:
# <style type="text/css">
# #T_5c1f9_row0_col0, #T_5c1f9_row0_col1, #T_5c1f9_row2_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_5c1f9_row0_col2 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_5c1f9_row1_col0, #T_5c1f9_row1_col1, #T_5c1f9_row1_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_5c1f9_row2_col0 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_5c1f9_row2_col1 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_5c1f9_row3_col0 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_5c1f9_row3_col1 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_5c1f9_row3_col2 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# </style>
# <table id="T_5c1f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c1f9_level0_col0" class="col_heading level0 col0" colspan="3">mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Track</th>
# ...

# %%
track_plotter.print_result(ResultParam.MeanError, InputFilter.InputCategorized, aggfunc='mean', color=True, plot=True)
# Out:
# <style type="text/css">
# #T_d91ac_row0_col0, #T_d91ac_row0_col1, #T_d91ac_row0_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d91ac_row1_col0, #T_d91ac_row1_col1, #T_d91ac_row1_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_d91ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d91ac_level0_col0" class="col_heading level0 col0" colspan="3">mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Track</th>
#       <th id="T_d91ac_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_d91ac_level1_col1" class="col_heading level1 col1" >2</th>
#       <th id="T_d91ac_level1_col2" class="col_heading level1 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >InputCategorized</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
# ...

# %%
track_plotter.print_result(ResultParam.MedianError, InputFilter.InputCategorized, aggfunc='mean', color=True, plot=True)
# Out:
# <style type="text/css">
# #T_50306_row0_col0, #T_50306_row0_col1, #T_50306_row0_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_50306_row1_col0, #T_50306_row1_col1, #T_50306_row1_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_50306">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50306_level0_col0" class="col_heading level0 col0" colspan="3">mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Track</th>
#       <th id="T_50306_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_50306_level1_col1" class="col_heading level1 col1" >2</th>
#       <th id="T_50306_level1_col2" class="col_heading level1 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >InputCategorized</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
# ...

# %%
track_plotter.print_result(ResultParam.Time, InputFilter.InputCategorized, aggfunc='mean', color=True, plot=True)
# Out:
# <style type="text/css">
# #T_86cf7_row0_col0, #T_86cf7_row0_col1, #T_86cf7_row0_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_86cf7_row1_col0, #T_86cf7_row1_col1, #T_86cf7_row1_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_86cf7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86cf7_level0_col0" class="col_heading level0 col0" colspan="3">mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Track</th>
#       <th id="T_86cf7_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_86cf7_level1_col1" class="col_heading level1 col1" >2</th>
#       <th id="T_86cf7_level1_col2" class="col_heading level1 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >InputCategorized</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
# ...
